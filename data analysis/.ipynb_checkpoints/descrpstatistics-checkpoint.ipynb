# %%
import numpy as np
import pandas as pd
import scipy
from scipy import stats

# %%
address='C:/Users/PC1/python/data analysis/Ex_Files_Python_Data_Science_EssT_Pt_1/Exercise Files/Data/mtcars.csv'
df=pd.read_csv(address)

# %%
df.drop(columns=['Unnamed: 0']).sum()
# Out:
# mpg      642.900
# cyl      198.000
# disp    7383.100
# hp      4694.000
# drat     115.090
# wt       102.952
# qsec     571.160
# vs        14.000
# am        13.000
# gear     118.000
# carb      90.000
# dtype: float64

# %%
df.drop(columns=['Unnamed: 0']).median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
## Extraer la ubicación del valor máximo
df.mpg.idxmax()
# Out:
# 19

# %%
df.drop(columns=['Unnamed: 0']).std()
df.drop(columns=['Unnamed: 0']).var()
# Out:
# mpg        36.324103
# cyl         3.189516
# disp    15360.799829
# hp       4700.866935
# drat        0.285881
# wt          0.957379
# qsec        3.193166
# vs          0.254032
# am          0.248992
# gear        0.544355
# carb        2.608871
# dtype: float64

# %%
df.mpg.value_counts()
# Out:
# mpg
# 21.0    2
# 22.8    2
# 21.4    2
# 19.2    2
# 10.4    2
# 15.2    2
# 30.4    2
# 18.1    1
# 18.7    1
# 17.8    1
# 24.4    1
# 14.3    1
# 17.3    1
# 16.4    1
# 14.7    1
# 32.4    1
# 33.9    1
# 21.5    1
# 15.5    1
# 13.3    1
# 27.3    1
# 26.0    1
# 15.8    1
# 19.7    1
# 15.0    1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# ## Categorical

# %%
cars_cat=df[['cyl','vs','am','gear','carb']]

# %%
cars_cat.groupby('gear').describe()
# Out:
#        cyl                                                 vs            ...  \
#      count      mean       std  min  25%  50%  75%  max count      mean  ...
# gear                                                                     ...
# 3     15.0  7.466667  1.187234  4.0  8.0  8.0  8.0  8.0  15.0  0.200000  ...
# 4     12.0  4.666667  0.984732  4.0  4.0  4.0  6.0  6.0  12.0  0.833333  ...
# 5      5.0  6.000000  2.000000  4.0  4.0  6.0  8.0  8.0   5.0  0.200000  ...
#
#        am       carb
#       75%  max count      mean       std  min  25%  50%  75%  max
# gear
# 3     0.0  0.0  15.0  2.666667  1.175139  1.0  2.0  3.0  4.0  4.0
# 4     1.0  1.0  12.0  2.333333  1.302678  1.0  1.0  2.0  4.0  4.0
# 5     1.0  1.0   5.0  4.400000  2.607681  2.0  2.0  4.0  6.0  8.0
#
# [3 rows x 32 columns]

# %% [markdown]
# ## Transforming in categorical data type

# %%
df['group'] = pd.Series(df.gear, dtype="category")

# %%
df['group']
# Out:
# 0     4
# 1     4
# 2     4
# 3     3
# 4     3
# 5     3
# 6     3
# 7     4
# 8     4
# 9     4
# 10    4
# 11    3
# 12    3
# 13    3
# 14    3
# 15    3
# 16    3
# 17    4
# 18    4
# 19    4
# 20    3
# 21    3
# 22    3
# 23    3
# 24    3
# 25    4
# 26    5
# 27    5
# 28    5
# 29    5
# 30    5
# 31    4
# Name: group, dtype: category
# Categories (3, int64): [3, 4, 5]

# %%
pd.crosstab(df['am'], df["gear"])
# Out:
# gear   3  4  5
# am
# 0     15  4  0
# 1      0  8  5
